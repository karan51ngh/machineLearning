# %% [markdown]
# ###0.Importing Library

# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###1.Create DataFrame

# %%
data={
    'roll_no' : [3,2,7,11],
    'ppr_id' : [34,21,10,11],
    'marks' : [30,23,17,27],
}

# %%
data
# Out:
# {'marks': [30, 23, 17, 27],
#  'ppr_id': [34, 21, 10, 11],
#  'roll_no': [3, 2, 7, 11]}

# %%
df1=pd.DataFrame(data)

# %%
df1
# Out:
#    roll_no  ppr_id  marks
# 0        3      34     30
# 1        2      21     23
# 2        7      10     17
# 3       11      11     27

# %% [markdown]
# ###2.Setting Index

# %%
df2=pd.DataFrame(data,index= [ 'a','b','c','d'])

# %%
df2
# Out:
#    roll_no  ppr_id  marks
# a        3      34     30
# b        2      21     23
# c        7      10     17
# d       11      11     27

# %% [markdown]
# ###3.Extracting Info

# %%
df2
# Out:
#    roll_no  ppr_id  marks
# a        3      34     30
# b        2      21     23
# c        7      10     17
# d       11      11     27

# %%
df2.loc['b']
# Out:
# roll_no     2
# ppr_id     21
# marks      23
# Name: b, dtype: int64

# %%
df2.iloc[0:2,2:3]
# Out:
#    marks
# a     30
# b     23

# %% [markdown]
# ###4.Working On CSV

# %% [markdown]
# ####4.1.Loading Data

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MLPL5-3/iris_dataset.csv')

# %%
#view data
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 140           6.7          3.1           5.6          2.4
# 141           6.9          3.1           5.1          2.3
# 142           5.8          2.7           5.1          1.9
# 143           6.8          3.2           5.9          2.3
# 144           6.7          3.3           5.7          2.5
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8

# %% [markdown]
# ####4.2.Data Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %% [markdown]
# ####4.3.Data Description

# %%
df.head(6)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
# 5           5.4          3.9           1.7          0.4

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ####4.4.Data Selection

# %%
df['sepal_width'][:6]
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# 5    3.9
# Name: sepal_width, dtype: float64

# %%
df[['sepal_width']][:6]
# Out:
#    sepal_width
# 0          3.5
# 1          3.0
# 2          3.2
# 3          3.1
# 4          3.6
# 5          3.9

# %%
df[['sepal_width', 'petal_width']].head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
df.iloc[:10, [1, 3]]
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2
# 5          3.9          0.4
# 6          3.4          0.3
# 7          3.4          0.2
# 8          2.9          0.2
# 9          3.1          0.1

# %% [markdown]
# ####4.5.Missing Values

# %% [markdown]
# #####4.5.1.NULL Values

# %%
data = {
    'roll_no': [3, 2, 7, 11],
    'ppr_id': [34, 21, 10, 11], 
    'marks': [np.nan, 23, 17, 27]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    roll_no  ppr_id  marks
# 0        3      34    NaN
# 1        2      21   23.0
# 2        7      10   17.0
# 3       11      11   27.0

# %% [markdown]
# #####4.5.2.isnull()

# %%
df.isnull()
# Out:
#    roll_no  ppr_id  marks
# 0    False   False   True
# 1    False   False  False
# 2    False   False  False
# 3    False   False  False

# %% [markdown]
# #####4.5.3.fillna()

# %%
df2 = df.fillna(20)

# %%
df2
# Out:
#    roll_no  ppr_id  marks
# 0        3      34   20.0
# 1        2      21   23.0
# 2        7      10   17.0
# 3       11      11   27.0

# %% [markdown]
# 4.5.4.Dropping NULL Values

# %%
df
# Out:
#    roll_no  ppr_id  marks
# 0        3      34    NaN
# 1        2      21   23.0
# 2        7      10   17.0
# 3       11      11   27.0

# %%
t=df.dropna(axis=0)

# %%
t
# Out:
#    roll_no  ppr_id  marks
# 1        2      21   23.0
# 2        7      10   17.0
# 3       11      11   27.0

# %%
y=df.dropna(axis=1)

# %%
y
# Out:
#    roll_no  ppr_id
# 0        3      34
# 1        2      21
# 2        7      10
# 3       11      11
