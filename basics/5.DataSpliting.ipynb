# %% [markdown]
# ##0.Importing Libraries

# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##1.Loading Data

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MLPL5-4/housing.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    longitude  latitude  ...  median_house_value  ocean_proximity
# 0    -122.23     37.88  ...            452600.0         NEAR BAY
# 1    -122.22     37.86  ...            358500.0         NEAR BAY
# 2    -122.24     37.85  ...            352100.0         NEAR BAY
# 3    -122.25     37.85  ...            341300.0         NEAR BAY
# 4    -122.25     37.85  ...            342200.0         NEAR BAY
#
# [5 rows x 10 columns]

# %%
df.describe()
# Out:
#           longitude      latitude  ...  median_income  median_house_value
# count  20640.000000  20640.000000  ...   20640.000000        20640.000000
# mean    -119.569704     35.631861  ...       3.870671       206855.816909
# std        2.003532      2.135952  ...       1.899822       115395.615874
# min     -124.350000     32.540000  ...       0.499900        14999.000000
# 25%     -121.800000     33.930000  ...       2.563400       119600.000000
# 50%     -118.490000     34.260000  ...       3.534800       179700.000000
# 75%     -118.010000     37.710000  ...       4.743250       264725.000000
# max     -114.310000     41.950000  ...      15.000100       500001.000000
#
# [8 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.ndim
# Out:
# 2

# %%
df.fillna(value=537.870553)
# Out:
#        longitude  latitude  ...  median_house_value  ocean_proximity
# 0        -122.23     37.88  ...            452600.0         NEAR BAY
# 1        -122.22     37.86  ...            358500.0         NEAR BAY
# 2        -122.24     37.85  ...            352100.0         NEAR BAY
# 3        -122.25     37.85  ...            341300.0         NEAR BAY
# 4        -122.25     37.85  ...            342200.0         NEAR BAY
# ...          ...       ...  ...                 ...              ...
# 20635    -121.09     39.48  ...             78100.0           INLAND
# 20636    -121.21     39.49  ...             77100.0           INLAND
# 20637    -121.22     39.43  ...             92300.0           INLAND
# 20638    -121.32     39.43  ...             84700.0           INLAND
# 20639    -121.24     39.37  ...             89400.0           INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# ##2.Approach 1- Manual Splitting with Slicing

# %% [markdown]
# ###2.1.Splitting Data into Input Output

# %%
#input
x=df.drop('median_house_value',axis=1)

# %%
x.head()
# Out:
#    longitude  latitude  ...  median_income  ocean_proximity
# 0    -122.23     37.88  ...         8.3252         NEAR BAY
# 1    -122.22     37.86  ...         8.3014         NEAR BAY
# 2    -122.24     37.85  ...         7.2574         NEAR BAY
# 3    -122.25     37.85  ...         5.6431         NEAR BAY
# 4    -122.25     37.85  ...         3.8462         NEAR BAY
#
# [5 rows x 9 columns]

# %%
x.shape
# Out:
# (20640, 9)

# %%
#output
y=df['median_house_value']

# %%
y.head()
# Out:
# 0    452600.0
# 1    358500.0
# 2    352100.0
# 3    341300.0
# 4    342200.0
# Name: median_house_value, dtype: float64

# %%
y.shape
# Out:
# (20640,)

# %% [markdown]
# ###2.2.Further Splitting into Training and Testing data

# %%
#input -> input_train + input_test
x_train = x.loc[0:20000, :]
x_test = x.loc[20000:, :]

# output -> output_train + output_test
y_train = y.loc[0:20000]
y_test = y.loc[20000:]

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (20001, 9)
# (20001,)
# (640, 9)
# (640,)

# %% [markdown]
# ##3.Approach 2- Splitting using SKLearn

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=101)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (16512, 9)
# (16512,)
# (4128, 9)
# (4128,)
